# %%
import pandas as pd
df=pd.read_csv('bs.csv',encoding='iso-8859-13')
df
# Out:
#                  Source              Category              Date  \
# 0     businessStandards         ['Companies']   1/31/2018 11:25
# 1     businessStandards         ['Companies']   1/31/2018 11:03
# 2     businessStandards         ['Companies']   1/31/2018 10:26
# 3     businessStandards         ['Companies']   1/31/2018 10:13
# 4     businessStandards         ['Companies']    1/31/2018 9:46
# 5     businessStandards         ['Companies']    1/31/2018 9:22
# 6     businessStandards         ['Companies']    1/31/2018 8:26
# 7     businessStandards         ['Companies']    1/31/2018 7:18
# 8     businessStandards         ['Companies']    1/31/2018 6:25
# 9     businessStandards  ['Economy & Policy']   1/31/2018 11:22
# 10    businessStandards  ['Economy & Policy']   1/31/2018 10:53
# 11    businessStandards  ['Economy & Policy']    1/31/2018 8:06
# 12    businessStandards  ['Economy & Policy']    1/31/2018 6:57
# 13    businessStandards           ['Markets']   1/31/2018 11:10
# ...

# %%
df1=pd.read_csv('Business_standard(2018).csv',encoding='iso-8859-13')
df1
# Out:
#                   Source              Category                     Date  \
# 0      businessStandards         ['Companies']          1/31/2018 11:25
# 1      businessStandards         ['Companies']          1/31/2018 11:03
# 2      businessStandards         ['Companies']          1/31/2018 10:26
# 3      businessStandards         ['Companies']          1/31/2018 10:13
# 4      businessStandards         ['Companies']           1/31/2018 9:46
# 5      businessStandards         ['Companies']           1/31/2018 9:22
# 6      businessStandards         ['Companies']           1/31/2018 8:26
# 7      businessStandards         ['Companies']           1/31/2018 7:18
# 8      businessStandards         ['Companies']           1/31/2018 6:25
# 9      businessStandards  ['Economy & Policy']          1/31/2018 11:22
# 10     businessStandards  ['Economy & Policy']          1/31/2018 10:53
# 11     businessStandards  ['Economy & Policy']           1/31/2018 8:06
# ...

# %%
df2=df.append(df1,ignore_index=True)

# %%
df2
# Out:
#                   Source              Category                     Date  \
# 0      businessStandards         ['Companies']          1/31/2018 11:25
# 1      businessStandards         ['Companies']          1/31/2018 11:03
# 2      businessStandards         ['Companies']          1/31/2018 10:26
# 3      businessStandards         ['Companies']          1/31/2018 10:13
# 4      businessStandards         ['Companies']           1/31/2018 9:46
# 5      businessStandards         ['Companies']           1/31/2018 9:22
# 6      businessStandards         ['Companies']           1/31/2018 8:26
# 7      businessStandards         ['Companies']           1/31/2018 7:18
# 8      businessStandards         ['Companies']           1/31/2018 6:25
# 9      businessStandards  ['Economy & Policy']          1/31/2018 11:22
# 10     businessStandards  ['Economy & Policy']          1/31/2018 10:53
# 11     businessStandards  ['Economy & Policy']           1/31/2018 8:06
# ...

# %%
df2.to_csv('bs_1.csv')
